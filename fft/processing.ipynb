# %%
import dsp
# %matplotlib widget

s,f = dsp.fft("data/pdmout70k-ciconly.raw", 300000, 16, False)
ss,ff = dsp.fft("data/PDM-output-70k.raw", 4.8e6, 32, True)

dsp.plot_compare(s,ss ,f,ff)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import dsp
# %matplotlib widget

s,f = dsp.fft("data/pdmout70k-ciconly.raw", 300000, 16, False)
ss,ff = dsp.fft("data/espfilt-pdmout70k.raw", 300000, 16, False)

dsp.plot_compare(s,ss ,f,ff)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import dsp
# %matplotlib widget

ss,ff = dsp.fft("data/13-02-rtos-loop-ok/pdm32bits-rtos/pdm32bits-rtos_5khz_alto01.raw", 5e6, 32)
s,f = dsp.fft("data/resultado_new_cicfir.raw", 312500, 16, False)

dsp.plot_compare(ss,s,ff,f)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
